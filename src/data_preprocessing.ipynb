# %% [markdown]
# # 0. Gather information about the dataset

# %% [markdown]
# Gather information about the dataset.
# - Number of images in test set and train set
# - Number of different formats
# - Number of cats and dogs in train and test set
# - Different types of breeds in each set and their count
# - Different type of image sizes in each set and their count

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
test_path = "../Dataset/Test/color"
test_label_path = "../Dataset/Test/label"
train_path = "../Dataset/TrainVal/color"
train_label_path = "../Dataset/TrainVal/label"

# %% [markdown]
# ## Number of images in test set and train set

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

from PIL import Image
# Out:
# Number of images in test set: 3694
# Number of images in train set: 3673

# %%
test_path = "../Dataset/Test/color"
test_label_path = "../Dataset/Test/label"
train_path = "../Dataset/TrainVal/color"
train_label_path = "../Dataset/TrainVal/label"

# %%
def get_file_format(filename):
    """Extracts file format from the filename."""
    return filename.split(".")[-1]

def get_file_dimensions(filename):
    """Processes the filename to extract dimensions."""
    return plt.imread(filename).shape
    

def get_breed_name(filename):
    """Extracts breed name by removing the last part (assumed to be an ID)."""
    breed = filename.split("_")[:-1]  # Remove the last split part
    return "_".join(breed)

def count_file_formats_dimensions_and_breeds(image_dir):
    """
    Counts occurrences of file formats and breeds in the given directory.
    
    Args:
        image_dir (str): Path to the dataset directory.

    Returns:
        tuple: Two dictionaries, one for file formats and one for breed names.
    """
    format_count = {}
    dimension_count = {}
    breed_count = {}

    for filename in os.listdir(image_dir):
        file_format = get_file_format(filename)
        dimensions = get_file_dimensions(os.path.join(image_dir, filename))
        breed_name = get_breed_name(filename)

        # Count file format occurrences
        format_count[file_format] = format_count.get(file_format, 0) + 1

        # Count dimension occurrences
        dimension_count[dimensions] = dimension_count.get(dimensions, 0) + 1

        # Count breed occurrences
        breed_count[breed_name] = breed_count.get(breed_name, 0) + 1

    return format_count, dimension_count, breed_count

# %% [markdown]
# ## 0.1 Get classes in train and test set, and invalid images

# %%
def classify_image(image_path):
    """
    Classifies an image as either 'cat' or 'dog' based on pixel colors in the label.
    If the image is invalid, returns (0, 0).

    - Red pixels (R > 0, G = 0, B = 0, A = 1) → Cat
    - Green pixels (R = 0, G > 0, B = 0, A = 1) → Dog
    - White pixels (1,1,1,1) → Silhouette
    - Black pixels (0,0,0,1) → Background
    - Any other pixel values → Invalid

    Args:
        image_path (str): Path to the image label file.

    Returns:
        tuple: (is_cat, is_dog)
               is_cat, is_dog: Either 1 or 0.
               If the image is invalid, both values will be 0.
    """
    # Load the image label
    label = plt.imread(image_path)

    # Ensure image has an alpha channel
    if label.shape[-1] != 4:
        return 0, 0  # Invalid image due to missing alpha channel

    # Extract RGBA channels
    R, G, B, A = label[:, :, 0], label[:, :, 1], label[:, :, 2], label[:, :, 3]

    # Masks for valid colors
    black_mask = (R == 0) & (G == 0) & (B == 0) & (A == 1)
    white_mask = (R == 1) & (G == 1) & (B == 1) & (A == 1)
    red_mask = (R > 0) & (G == 0) & (B == 0) & (A == 1)
    green_mask = (R == 0) & (G > 0) & (B == 0) & (A == 1)

    # Check if there are any red or green pixels
    has_cat = np.any(red_mask)
    has_dog = np.any(green_mask)

    # Check for invalid pixels (not in the valid set)
    valid_mask = white_mask | black_mask | red_mask | green_mask
    is_invalid = not np.all(valid_mask) or (not has_cat and not has_dog)

    # If invalid, return (0, 0)
    if is_invalid:
        return 0, 0

    return int(has_cat), int(has_dog)

# %% [markdown]
# ### 0.1.1 Get classes and invalid images in test set

# %%
# Initialize counters
cat_dog_count_test = {"cat": 0, "dog": 0}

# Get format and breed counts
format_and_count_test, dimension_and_count_test, breed_and_count_test = count_file_formats_dimensions_and_breeds(test_path)

# List of images with invalid labels
invalid_test_images = []

# Iterate through test images
for filename in os.listdir(test_path):
    label_image_path = os.path.join(test_label_path, filename.replace(".jpg", ".png"))

    # Classify the image
    cat, dog = classify_image(label_image_path)

    if cat == 0 and dog == 0:
        invalid_test_images.append(filename)
        continue

    # Update counters
    cat_dog_count_test["cat"] += cat
    cat_dog_count_test["dog"] += dog

# Display results
print("Cat/Dog count in test set:", cat_dog_count_test)
print("There are", len(invalid_test_images), "invalid images in the test set:", invalid_test_images)
# Out:
# Cat/Dog count in test set: {'cat': 1203, 'dog': 2491}
# There are 0 invalid images in the test set: []

# %% [markdown]
# ### 0.1.2 Get classes and invalid images in train set

# %%
# Initialize counters
cat_dog_count_train = {"cat": 0, "dog": 0}

# Get format and breed counts
format_and_count_train, dimension_and_count_train, breed_and_count_train = count_file_formats_dimensions_and_breeds(train_path)

# List of images with invalid labels
invalid_train_images = []

# Iterate through train images
for filename in os.listdir(train_path):
    label_image_path = os.path.join(train_label_path, filename.replace(".jpg", ".png"))

    # Classify the image
    cat, dog = classify_image(label_image_path)

    if cat == 0 and dog == 0:
        invalid_train_images.append(filename)
        continue

    # Update counters
    cat_dog_count_train["cat"] += cat
    cat_dog_count_train["dog"] += dog

# Display results
print("Cat/Dog count in train set:", cat_dog_count_train)
print("There are", len(invalid_train_images), "invalid images in the train set:", invalid_train_images)
# Out:
# Cat/Dog count in train set: {'cat': 1185, 'dog': 2488}
# There are 0 invalid images in the train set: []

# %% [markdown]
# ## 0.2 Summary

# %%
files_with_no_label_test = number_of_images_in_test - cat_dog_count_test["cat"] - cat_dog_count_test["dog"]
files_with_no_label_train = number_of_images_in_train - cat_dog_count_train["cat"] - cat_dog_count_train["dog"]

# Display results
print("Files with no label in test set:", files_with_no_label_test)
print(invalid_test_images)
print("Files with no label in train set:", files_with_no_label_train)
print(invalid_train_images)

# Delate invalid images and labels
for filename in invalid_test_images:
    os.remove(os.path.join(test_path, filename))
    os.remove(os.path.join(test_label_path, filename.replace(".jpg", ".png")))
              
for filename in invalid_train_images:
    os.remove(os.path.join(train_path, filename))
    os.remove(os.path.join(train_label_path, filename.replace(".jpg", ".png")))

number_of_valid_images_in_test = len(os.listdir(test_path))
number_of_valid_images_in_train = len(os.listdir(train_path))
# Out:
# Files with no label in test set: 0
# []
# Files with no label in train set: 0
# []

# %% [markdown]
# ## Summary

# %%
# Count the number of images in test and train sets
number_of_images_in_test = len(os.listdir(test_path))
number_of_images_in_train = len(os.listdir(train_path))

# Display counts
print("Number of images in test set:", number_of_images_in_test)
print("Number of images in train set:", number_of_images_in_train)

print("\nFormat and Breed counts in test set:")
print(format_and_count_test)
print(breed_and_count_test)

print("\nFormat and Breed counts in train set:")
print(format_and_count_train)
print(breed_and_count_train)

print("\nCat/dog count in test set: ", cat_dog_count_test)
print("Cat/dog count in train set: ", cat_dog_count_train)

files_with_no_label_test = number_of_images_in_test - cat_dog_count_test["cat"] - cat_dog_count_test["dog"]
files_with_no_label_train = number_of_images_in_train - cat_dog_count_train["cat"] - cat_dog_count_train["dog"]

print("\nFiles with no label in test set: ", files_with_no_label_test)
print("Files with no label in train set: ", files_with_no_label_train)


print("\nDimension counts in test set:")
print(dimension_and_count_test)

print("\nDimension counts in train set:")
print(dimension_and_count_train)

print("\nThere are {} different shapes of images in the test set and {} in the train set.".format(len(dimension_and_count_test), len(dimension_and_count_train)))
print("The 5 most common shapes in the test set are:")
for i in sorted(dimension_and_count_test.items(), key=lambda x: x[1], reverse=True)[:20]:
    print(i)
print("The 5 most common shapes in the train set are:")
for i in sorted(dimension_and_count_train.items(), key=lambda x: x[1], reverse=True)[:20]:
    print(i)
# Out:
# Total number of images in test set:  3694
# Total number of images in train set:  3673
# Number of valid images in test set:  3694
# Number of valid images in train set:  3673
#
# Format and Breed counts in test set:
# {'jpg': 3694}
# {'pug': 100, 'Siamese': 101, 'leonberger': 100, 'Abyssinian': 99, 'miniature_pinscher': 100, 'wheaten_terrier': 99, 'shiba_inu': 100, 'saint_bernard': 98, 'pomeranian': 100, 'Sphynx': 100, 'Egyptian_Mau': 100, 'British_Shorthair': 100, 'Birman': 100, 'Bombay': 104, 'samoyed': 100, 'Russian_Blue': 100, 'Persian': 99, 'Maine_Coon': 100, 'Bengal': 100, 'english_cocker_spaniel': 104, 'american_pit_bull_terrier': 100, 'keeshond': 99, 'great_pyrenees': 100, 'boxer': 100, 'chihuahua': 100, 'german_shorthaired': 100, 'yorkshire_terrier': 100, 'staffordshire_bull_terrier': 89, 'beagle': 100, 'japanese_chin': 99, 'american_bulldog': 100, 'english_setter': 100, 'Ragdoll': 100, 'basset_hound': 100, 'newfoundland': 104, 'scottish_terrier': 99, 'havanese': 100}
#
# Format and Breed counts in train set:
# {'jpg': 3673}
# {'basset_hound': 100, 'Siamese': 99, 'shiba_inu': 100, 'Birman': 100, 'saint_bernard': 98, 'Egyptian_Mau': 90, 'scottish_terrier': 100, 'pomeranian': 100, 'german_shorthaired': 100, 'english_setter': 100, 'newfoundland': 96, 'British_Shorthair': 100, 'boxer': 100, 'great_pyrenees': 100, 'leonberger': 99, 'japanese_chin': 100, 'Ragdoll': 100, 'english_cocker_spaniel': 96, 'havanese': 100, 'Maine_Coon': 100, 'american_pit_bull_terrier': 100, 'american_bulldog': 100, 'keeshond': 100, 'miniature_pinscher': 99, 'samoyed': 100, 'Abyssinian': 100, 'Sphynx': 100, 'beagle': 100, 'Bombay': 96, 'Bengal': 100, 'staffordshire_bull_terrier': 100, 'Persian': 100, 'pug': 100, 'Russian_Blue': 100, 'chihuahua': 100, 'yorkshire_terrier': 100, 'wheaten_terrier': 100}
#
# Cat/dog count in test set:  {'cat': 1203, 'dog': 2491}
# Cat/dog count in train set:  {'cat': 1185, 'dog': 2488}
202, 157, 3): 1, (340, 500, 3): 5, (500, 415, 3): 2, (320, 500, 3): 2, (384, 500, 3): 3, (436, 500, 3): 3, (500, 463, 3): 1, (235, 300, 3): 1, (287, 300, 3): 2, (500, 445, 3): 1, (500, 368, 3): 1, (442, 500, 3): 2, (500, 299, 3): 2, (410, 500, 3): 4, (237, 237, 3): 1, (394, 500, 3): 1, (300, 289, 3): 2, (500, 342, 3): 3, (500, 394, 3): 3, (262, 300, 3): 2, (300, 214, 3): 3, (300, 400, 3): 3, (500, 319, 3): 1, (308, 360, 3): 1, (480, 360, 3): 1, (500, 438, 3): 2, (373, 500, 3): 2, (300, 254, 3): 1, (272, 400, 3): 1, (300, 258, 3): 1, (300, 224, 3): 1, (500, 493, 3): 2, (500, 318, 3): 1, (459, 500, 3): 1, (500, 391, 3): 5, (222, 290, 3): 1, (500, 403, 3): 4, (482, 720, 3): 1, (367, 500, 3): 4, (343, 500, 3): 6, (409, 500, 3): 2, (700, 525, 3): 1, (338, 500, 3): 3, (262, 500, 3): 1, (500, 344, 3): 2, (500, 348, 3): 1, (270, 360, 3): 2, (434, 600, 3): 1, (410, 360, 3): 1, (500, 443, 3): 1, (398, 500, 3): 2, (377, 500, 3): 2, (470, 500, 3): 2, (433, 500, 3): 5, (300, 234, 3): 1, (348, 500, 3): 4, (500, 351, 3 ...
#
# There are 659 different shapes of images in the test set and 706 in the train set.
# The 5 most common shapes in the test set are:
# ((375, 500, 3), 653)
# ((333, 500, 3), 584)
# ((500, 333, 3), 287)
# ((500, 375, 3), 260)
# ((334, 500, 3), 129)
# ((332, 500, 3), 111)
# ((500, 334, 3), 85)
# ((225, 300, 3), 65)
# ((335, 500, 3), 57)
# ((500, 500, 3), 57)
# ((500, 332, 3), 52)
# ((500, 335, 3), 39)
# ((400, 500, 3), 23)
# ((376, 500, 3), 19)
# ((331, 500, 3), 18)
# ((374, 500, 3), 17)
# ((357, 500, 3), 15)
# ((500, 400, 3), 15)
# ((500, 357, 3), 15)
# ((300, 225, 3), 14)
# The 5 most common shapes in the train set are:
# ((375, 500, 3), 769)
# ((333, 500, 3), 487)
# ((500, 375, 3), 249)
# ((500, 333, 3), 221)
# ((225, 300, 3), 201)
# ((334, 500, 3), 123)
# ((332, 500, 3), 74)
# ((500, 334, 3), 66)
# ((335, 500, 3), 40)
# ((500, 332, 3), 39)
# ((300, 225, 3), 35)
# ((500, 500, 3), 31)
# ((330, 500, 3), 22)
# ((400, 500, 3), 16)
# ((281, 500, 3), 15)
# ((200, 300, 3), 14)
# ((500, 335, 3), 14)
# ((500, 400, 3), 12)
# ((500, 357, 3), 11)
# ((357, 500, 3), 10)

# %% [markdown]
# # 1. Dataset preprocessing and augmentation

# %% [markdown]
# ## 1.1 Dataset preprocessing (convert RGBA to RGB and resize)

# %% [markdown]
# ### 1.1.1 Remove invalid images

# %%
files_with_no_label_test = number_of_images_in_test - cat_dog_count_test["cat"] - cat_dog_count_test["dog"]
files_with_no_label_train = number_of_images_in_train - cat_dog_count_train["cat"] - cat_dog_count_train["dog"]

# Display results
print("Files with no label in test set:", files_with_no_label_test)
print(invalid_test_images)
print("Files with no label in train set:", files_with_no_label_train)
print(invalid_train_images)

# Delate invalid images and labels
for filename in invalid_test_images:
    os.remove(os.path.join(test_path, filename))
    os.remove(os.path.join(test_label_path, filename.replace(".jpg", ".png")))
              
for filename in invalid_train_images:
    os.remove(os.path.join(train_path, filename))
    os.remove(os.path.join(train_label_path, filename.replace(".jpg", ".png")))

number_of_valid_images_in_test = len(os.listdir(test_path))
number_of_valid_images_in_train = len(os.listdir(train_path))

print("Total number of images in test set: ", number_of_images_in_test)
print("Total number of images in train set: ", number_of_images_in_train)

print("Number of valid images in test set: ", number_of_valid_images_in_test)
print("Number of valid images in train set: ", number_of_valid_images_in_train)
# Out:
# Files with no label in test set: 16
# ['Egyptian_Mau_167.jpg', 'Egyptian_Mau_20.jpg', 'saint_bernard_78.jpg', 'Egyptian_Mau_177.jpg', 'wheaten_terrier_195.jpg', 'Egyptian_Mau_139.jpg', 'keeshond_7.jpg', 'Egyptian_Mau_129.jpg', 'Abyssinian_34.jpg', 'Persian_259.jpg', 'Egyptian_Mau_191.jpg', 'staffordshire_bull_terrier_2.jpg', 'saint_bernard_60.jpg', 'Egyptian_Mau_145.jpg', 'japanese_chin_199.jpg', 'staffordshire_bull_terrier_22.jpg']
# Files with no label in train set: 7
# ['Egyptian_Mau_165.jpg', 'Egyptian_Mau_162.jpg', 'leonberger_18.jpg', 'miniature_pinscher_14.jpg', 'saint_bernard_15.jpg', 'Egyptian_Mau_196.jpg', 'saint_bernard_108.jpg']
# Total number of images in test set:  3710
# Total number of images in train set:  3680
# Number of valid images in test set:  3694
# Number of valid images in train set:  3673

# %% [markdown]
# ### 1.1.2 Convert RGBA to RGB

# %% [markdown]
# We noticed that there are some images with RGBA mode, we need to convert them to RGB in order to be able to process them

# %%
# remove 90% of images of each cat/dog breed
from pathlib import Path

# Get the 10% of the images of each breed
_, _, breeds_test = count_file_formats_dimensions_and_breeds(test_path)
_, _, breeds_train = count_file_formats_dimensions_and_breeds(train_path)

print("breeds_test: ", breeds_test)
print("breeds_train: ", breeds_train)


for breed in breeds_test:
    count = breeds_test[breed]
    delete_number = int(count * 0.5)
    print()
    if count < 10:
        print("skiping breed: ", breed)
        continue
    # generate delete_number random numbers between 0 and count
    random_numbers = np.random.choice(np.arange(count), size=delete_number, replace=False)
    for i, filename in enumerate(list(Path(test_path).glob(breed + "*"))):
        filename = filename.name
        if get_breed_name(filename) == breed and i in random_numbers:
            os.remove(os.path.join(test_path, filename))
            os.remove(os.path.join(test_label_path, filename.replace(".jpg", ".png")))
            print("removed from test set: ", filename)

for breed in breeds_train:
    count = breeds_train[breed]
    if count < 10:
        print("skiping breed: ", breed)
        continue
    delete_number = int(count * 0.5)
    # generate delete_number random numbers between 0 and count
    random_numbers = np.random.choice(np.arange(count), size=delete_number, replace=False)
    for i, filename in enumerate(list(Path(train_path).glob(breed + "*"))):
        filename = filename.name
        if get_breed_name(filename) == breed and i in random_numbers:
            os.remove(os.path.join(train_path, filename))
            os.remove(os.path.join(train_label_path, filename.replace(".jpg", ".png")))
            print("removed from train set: ", filename)
# Out:
# breeds_test:  {'pug': 44, 'Siamese': 37, 'leonberger': 39, 'wheaten_terrier': 37, 'Abyssinian': 40, 'Sphynx': 41, 'Egyptian_Mau': 39, 'Birman': 41, 'shiba_inu': 39, 'pomeranian': 39, 'samoyed': 44, 'Russian_Blue': 41, 'english_cocker_spaniel': 36, 'keeshond': 39, 'american_pit_bull_terrier': 38, 'great_pyrenees': 42, 'Maine_Coon': 41, 'boxer': 41, 'chihuahua': 43, 'yorkshire_terrier': 46, 'german_shorthaired': 40, 'miniature_pinscher': 38, 'beagle': 43, 'japanese_chin': 46, 'saint_bernard': 38, 'american_bulldog': 45, 'Persian': 41, 'basset_hound': 41, 'english_setter': 44, 'newfoundland': 41, 'scottish_terrier': 40, 'Bombay': 42, 'Ragdoll': 40, 'Bengal': 37, 'staffordshire_bull_terrier': 41, 'havanese': 38, 'British_Shorthair': 38}
# breeds_train:  {'basset_hound': 41, 'Siamese': 38, 'shiba_inu': 42, 'scottish_terrier': 41, 'pomeranian': 39, 'newfoundland': 38, 'english_setter': 43, 'British_Shorthair': 42, 'great_pyrenees': 41, 'japanese_chin': 39, 'Maine_Coon': 42, 'havanese': 42, 'boxer': 39, 'american_pit_bull_terrier': 41, 'miniature_pinscher': 40, 'samoyed': 46, 'american_bulldog': 38, 'Sphynx': 39, 'beagle': 42, 'Bengal': 41, 'staffordshire_bull_terrier': 37, 'keeshond': 40, 'Persian': 41, 'Russian_Blue': 41, 'chihuahua': 41, 'yorkshire_terrier': 35, 'english_cocker_spaniel': 39, 'Ragdoll': 45, 'pug': 45, 'Bombay': 38, 'Abyssinian': 35, 'leonberger': 45, 'german_shorthaired': 39, 'saint_bernard': 38, 'Egyptian_Mau': 33, 'Birman': 43, 'wheaten_terrier': 40}
#
# removed from test set:  pug_52.jpg
# removed from test set:  pug_85.jpg
# removed from test set:  pug_47.jpg
# removed from test set:  pug_45.jpg
# removed from test set:  pug_92.jpg
# removed from test set:  pug_87.jpg
# removed from test set:  pug_78.jpg
# removed from test set:  pug_50.jpg
# removed from test set:  pug_55.jpg
# removed from test set:  pug_41.jpg
# removed from test set:  pug_42.jpg
# removed from test set:  pug_203.jpg
# removed from test set:  pug_27.jpg
# removed from test set:  pug_36.jpg
# removed from test set:  pug_39.jpg
# removed from test set:  pug_29.jpg
# removed from test set:  pug_193.jpg
# removed from test set:  pug_98.jpg
# removed from test set:  pug_99.jpg
# removed from test set:  pug_66.jpg
# removed from test set:  pug_4.jpg
# removed from test set:  pug_3.jpg
#
# removed from test set:  Siamese_53.jpg
# removed from test set:  Siamese_84.jpg
# removed from test set:  Siamese_233.jpg
# removed from test set:  Siamese_46.jpg
# removed from test set:  Siamese_78.jpg
# removed from test set:  Siamese_93.jpg
# removed from test set:  Siamese_218.jpg
# removed from test set:  Siamese_224.jpg
# removed from test set:  Siamese_41.jpg
# removed from test set:  Siamese_95.jpg
# removed from test set:  Siamese_31.jpg
# removed from test set:  Siamese_27.jpg
# removed from test set:  Siamese_240.jpg
# removed from test set:  Siamese_98.jpg
# removed from test set:  Siamese_70.jpg
# removed from test set:  Siamese_64.jpg
# removed from test set:  Siamese_48.jpg
# removed from test set:  Siamese_228.jpg
#
# removed from test set:  leonberger_6.jpg
# removed from test set:  leonberger_36.jpg
# removed from test set:  leonberger_26.jpg
# removed from test set:  leonberger_33.jpg
# removed from test set:  leonberger_94.jpg
# removed from test set:  leonberger_194.jpg
# removed from test set:  leonberger_78.jpg
# removed from test set:  leonberger_87.jpg
# removed from test set:  leonberger_52.jpg
# removed from test set:  leonberger_46.jpg
# removed from test set:  leonberger_84.jpg
# removed from test set:  leonberger_76.jpg
# removed from test set:  leonberger_77.jpg
# removed from test set:  leonberger_88.jpg
# removed from test set:  leonberger_75.jpg
# removed from test set:  leonberger_200.jpg
# removed from test set:  leonberger_71.jpg
# removed from test set:  leonberger_67.jpg
# removed from test set:  leonberger_99.jpg
#
# removed from test set:  wheaten_terrier_74.jpg
# removed from test set:  wheaten_terrier_62.jpg
# removed from test set:  wheaten_terrier_63.jpg
# removed from test set:  wheaten_terrier_72.jpg
# removed from test set:  wheaten_terrier_197.jpg
# removed from test set:  wheaten_terrier_23.jpg
# removed from test set:  wheaten_terrier_21.jpg
# removed from test set:  wheaten_terrier_25.jpg
# removed from test set:  wheaten_terrier_19.jpg
# removed from test set:  wheaten_terrier_5.jpg
# removed from test set:  wheaten_terrier_32.jpg
# removed from test set:  wheaten_terrier_40.jpg
# removed from test set:  wheaten_terrier_41.jpg
# removed from test set:  wheaten_terrier_69.jpg
# removed from test set:  wheaten_terrier_94.jpg
# removed from test set:  wheaten_terrier_46.jpg
# removed from test set:  wheaten_terrier_91.jpg
# removed from test set:  wheaten_terrier_85.jpg
#
# removed from test set:  Abyssinian_219.jpg
# removed from test set:  Abyssinian_60.jpg
# removed from test set:  Abyssinian_230.jpg
# removed from test set:  Abyssinian_77.jpg
# removed from test set:  Abyssinian_63.jpg
# removed from test set:  Abyssinian_99.jpg
# removed from test set:  Abyssinian_58.jpg
# removed from test set:  Abyssinian_71.jpg
# removed from test set:  Abyssinian_37.jpg
# removed from test set:  Abyssinian_22.jpg
# removed from test set:  Abyssinian_25.jpg
# removed from test set:  Abyssinian_32.jpg
# removed from test set:  Abyssinian_210.jpg
# removed from test set:  Abyssinian_54.jpg
# removed from test set:  Abyssinian_40.jpg
# removed from test set:  Abyssinian_205.jpg
# removed from test set:  Abyssinian_94.jpg
# removed from test set:  Abyssinian_90.jpg
# removed from test set:  Abyssinian_51.jpg
# removed from test set:  Abyssinian_78.jpg
#
# removed from test set:  Sphynx_25.jpg
# removed from test set:  Sphynx_30.jpg
# removed from test set:  Sphynx_37.jpg
# removed from test set:  Sphynx_36.jpg
# removed from test set:  Sphynx_250.jpg
# removed from test set:  Sphynx_251.jpg
# removed from test set:  Sphynx_236.jpg
# removed from test set:  Sphynx_91.jpg
# removed from test set:  Sphynx_46.jpg
# removed from test set:  Sphynx_237.jpg
# removed from test set:  Sphynx_235.jpg
# removed from test set:  Sphynx_92.jpg
# removed from test set:  Sphynx_51.jpg
# removed from test set:  Sphynx_78.jpg
# removed from test set:  Sphynx_83.jpg
# removed from test set:  Sphynx_56.jpg
# removed from test set:  Sphynx_95.jpg
# removed from test set:  Sphynx_98.jpg
# removed from test set:  Sphynx_213.jpg
# removed from test set:  Sphynx_249.jpg
#
# removed from test set:  Egyptian_Mau_198.jpg
# removed from test set:  Egyptian_Mau_210.jpg
# removed from test set:  Egyptian_Mau_199.jpg
# removed from test set:  Egyptian_Mau_212.jpg
# removed from test set:  Egyptian_Mau_26.jpg
# removed from test set:  Egyptian_Mau_214.jpg
# removed from test set:  Egyptian_Mau_33.jpg
# removed from test set:  Egyptian_Mau_68.jpg
# removed from test set:  Egyptian_Mau_82.jpg
# removed from test set:  Egyptian_Mau_94.jpg
# removed from test set:  Egyptian_Mau_47.jpg
# removed from test set:  Egyptian_Mau_53.jpg
# removed from test set:  Egyptian_Mau_44.jpg
# removed from test set:  Egyptian_Mau_49.jpg
# removed from test set:  Egyptian_Mau_6.jpg
# removed from test set:  Egyptian_Mau_89.jpg
# removed from test set:  Egyptian_Mau_63.jpg
# removed from test set:  Egyptian_Mau_88.jpg
# removed from test set:  Egyptian_Mau_209.jpg
#
# removed from test set:  Birman_198.jpg
# removed from test set:  Birman_89.jpg
# removed from test set:  Birman_67.jpg
# removed from test set:  Birman_98.jpg
# removed from test set:  Birman_7.jpg
# removed from test set:  Birman_64.jpg
# removed from test set:  Birman_65.jpg
# removed from test set:  Birman_28.jpg
# removed from test set:  Birman_23.jpg
# removed from test set:  Birman_31.jpg
# removed from test set:  Birman_30.jpg
# removed from test set:  Birman_27.jpg
# removed from test set:  Birman_191.jpg
# removed from test set:  Birman_69.jpg
# removed from test set:  Birman_8.jpg
# removed from test set:  Birman_80.jpg
# removed from test set:  Birman_52.jpg
# removed from test set:  Birman_53.jpg
# removed from test set:  Birman_93.jpg
# removed from test set:  Birman_78.jpg
#
# removed from test set:  shiba_inu_80.jpg
# removed from test set:  shiba_inu_69.jpg
# removed from test set:  shiba_inu_45.jpg
# removed from test set:  shiba_inu_79.jpg
# removed from test set:  shiba_inu_93.jpg
# removed from test set:  shiba_inu_91.jpg
# removed from test set:  shiba_inu_84.jpg
# removed from test set:  shiba_inu_20.jpg
# removed from test set:  shiba_inu_3.jpg
# removed from test set:  shiba_inu_21.jpg
# removed from test set:  shiba_inu_4.jpg
# removed from test set:  shiba_inu_27.jpg
# removed from test set:  shiba_inu_24.jpg
# removed from test set:  shiba_inu_39.jpg
# removed from test set:  shiba_inu_62.jpg
# removed from test set:  shiba_inu_88.jpg
# removed from test set:  shiba_inu_77.jpg
# removed from test set:  shiba_inu_49.jpg
# removed from test set:  shiba_inu_71.jpg
#
# removed from test set:  pomeranian_72.jpg
# removed from test set:  pomeranian_98.jpg
# removed from test set:  pomeranian_88.jpg
# removed from test set:  pomeranian_77.jpg
# removed from test set:  pomeranian_63.jpg
# removed from test set:  pomeranian_76.jpg
# removed from test set:  pomeranian_198.jpg
# removed from test set:  pomeranian_61.jpg
# removed from test set:  pomeranian_199.jpg
# removed from test set:  pomeranian_28.jpg
# removed from test set:  pomeranian_25.jpg
# removed from test set:  pomeranian_31.jpg
# removed from test set:  pomeranian_22.jpg
# removed from test set:  pomeranian_79.jpg
# removed from test set:  pomeranian_195.jpg
# removed from test set:  pomeranian_192.jpg
# removed from test set:  pomeranian_82.jpg
# removed from test set:  pomeranian_69.jpg
# removed from test set:  pomeranian_97.jpg
#
# removed from test set:  samoyed_59.jpg
# removed from test set:  samoyed_62.jpg
# removed from test set:  samoyed_199.jpg
# removed from test set:  samoyed_61.jpg
# removed from test set:  samoyed_8.jpg
# removed from test set:  samoyed_38.jpg
# removed from test set:  samoyed_1.jpg
# removed from test set:  samoyed_31.jpg
# removed from test set:  samoyed_3.jpg
# removed from test set:  samoyed_36.jpg
# removed from test set:  samoyed_37.jpg
# removed from test set:  samoyed_5.jpg
# removed from test set:  samoyed_50.jpg
# removed from test set:  samoyed_92.jpg
# removed from test set:  samoyed_51.jpg
# removed from test set:  samoyed_196.jpg
# removed from test set:  samoyed_42.jpg
# removed from test set:  samoyed_192.jpg
# removed from test set:  samoyed_43.jpg
# removed from test set:  samoyed_57.jpg
# removed from test set:  samoyed_41.jpg
# removed from test set:  samoyed_96.jpg
#
# removed from test set:  Russian_Blue_253.jpg
# removed from test set:  Russian_Blue_244.jpg
# removed from test set:  Russian_Blue_70.jpg
# removed from test set:  Russian_Blue_99.jpg
# removed from test set:  Russian_Blue_77.jpg
# removed from test set:  Russian_Blue_62.jpg
# removed from test set:  Russian_Blue_237.jpg
# removed from test set:  Russian_Blue_209.jpg
# removed from test set:  Russian_Blue_205.jpg
# removed from test set:  Russian_Blue_78.jpg
# removed from test set:  Russian_Blue_50.jpg
# removed from test set:  Russian_Blue_87.jpg
# removed from test set:  Russian_Blue_86.jpg
# removed from test set:  Russian_Blue_92.jpg
# removed from test set:  Russian_Blue_79.jpg
# removed from test set:  Russian_Blue_212.jpg
# removed from test set:  Russian_Blue_91.jpg
# removed from test set:  Russian_Blue_40.jpg
# removed from test set:  Russian_Blue_54.jpg
# removed from test set:  Russian_Blue_33.jpg
#
# removed from test set:  english_cocker_spaniel_39.jpg
# removed from test set:  english_cocker_spaniel_197.jpg
# removed from test set:  english_cocker_spaniel_195.jpg
# removed from test set:  english_cocker_spaniel_59.jpg
# removed from test set:  english_cocker_spaniel_58.jpg
# removed from test set:  english_cocker_spaniel_49.jpg
# removed from test set:  english_cocker_spaniel_88.jpg
# removed from test set:  english_cocker_spaniel_90.jpg
# removed from test set:  english_cocker_spaniel_4.jpg
# removed from test set:  english_cocker_spaniel_92.jpg
# removed from test set:  english_cocker_spaniel_97.jpg
# removed from test set:  english_cocker_spaniel_2.jpg
# removed from test set:  english_cocker_spaniel_25.jpg
# removed from test set:  english_cocker_spaniel_27.jpg
# removed from test set:  english_cocker_spaniel_163.jpg
# removed from test set:  english_cocker_spaniel_26.jpg
# removed from test set:  english_cocker_spaniel_21.jpg
# removed from test set:  english_cocker_spaniel_20.jpg
#
# removed from test set:  keeshond_23.jpg
# removed from test set:  keeshond_192.jpg
# removed from test set:  keeshond_19.jpg
# removed from test set:  keeshond_26.jpg
# removed from test set:  keeshond_32.jpg
# removed from test set:  keeshond_196.jpg
# removed from test set:  keeshond_33.jpg
# removed from test set:  keeshond_97.jpg
# removed from test set:  keeshond_68.jpg
# removed from test set:  keeshond_1.jpg
# removed from test set:  keeshond_42.jpg
# removed from test set:  keeshond_47.jpg
# removed from test set:  keeshond_9.jpg
# removed from test set:  keeshond_98.jpg
# removed from test set:  keeshond_70.jpg
# removed from test set:  keeshond_199.jpg
# removed from test set:  keeshond_198.jpg
# removed from test set:  keeshond_28.jpg
# removed from test set:  keeshond_39.jpg
#
# removed from test set:  american_pit_bull_terrier_99.jpg
# removed from test set:  american_pit_bull_terrier_59.jpg
# removed from test set:  american_pit_bull_terrier_60.jpg
# removed from test set:  american_pit_bull_terrier_48.jpg
# removed from test set:  american_pit_bull_terrier_203.jpg
# removed from test set:  american_pit_bull_terrier_49.jpg
# removed from test set:  american_pit_bull_terrier_63.jpg
# removed from test set:  american_pit_bull_terrier_28.jpg
# removed from test set:  american_pit_bull_terrier_24.jpg
# removed from test set:  american_pit_bull_terrier_33.jpg
# removed from test set:  american_pit_bull_terrier_22.jpg
# removed from test set:  american_pit_bull_terrier_20.jpg
# removed from test set:  american_pit_bull_terrier_6.jpg
# removed from test set:  american_pit_bull_terrier_46.jpg
# removed from test set:  american_pit_bull_terrier_191.jpg
# removed from test set:  american_pit_bull_terrier_92.jpg
# removed from test set:  american_pit_bull_terrier_192.jpg
# removed from test set:  american_pit_bull_terrier_97.jpg
# removed from test set:  american_pit_bull_terrier_197.jpg
#
# removed from test set:  great_pyrenees_198.jpg
# removed from test set:  great_pyrenees_36.jpg
# removed from test set:  great_pyrenees_33.jpg
# removed from test set:  great_pyrenees_200.jpg
# removed from test set:  great_pyrenees_68.jpg
# removed from test set:  great_pyrenees_9.jpg
# removed from test set:  great_pyrenees_78.jpg
# removed from test set:  great_pyrenees_44.jpg
# removed from test set:  great_pyrenees_90.jpg
# removed from test set:  great_pyrenees_47.jpg
# removed from test set:  great_pyrenees_5.jpg
# removed from test set:  great_pyrenees_49.jpg
# removed from test set:  great_pyrenees_74.jpg
# removed from test set:  great_pyrenees_48.jpg
# removed from test set:  great_pyrenees_65.jpg
# removed from test set:  great_pyrenees_1.jpg
# removed from test set:  great_pyrenees_2.jpg
# removed from test set:  great_pyrenees_29.jpg
# removed from test set:  great_pyrenees_28.jpg
# removed from test set:  great_pyrenees_193.jpg
# removed from test set:  great_pyrenees_194.jpg
#
# removed from test set:  Maine_Coon_262.jpg
# removed from test set:  Maine_Coon_267.jpg
# removed from test set:  Maine_Coon_266.jpg
# removed from test set:  Maine_Coon_29.jpg
# removed from test set:  Maine_Coon_8.jpg
# removed from test set:  Maine_Coon_28.jpg
# removed from test set:  Maine_Coon_66.jpg
# removed from test set:  Maine_Coon_239.jpg
# removed from test set:  Maine_Coon_48.jpg
# removed from test set:  Maine_Coon_60.jpg
# removed from test set:  Maine_Coon_77.jpg
# removed from test set:  Maine_Coon_85.jpg
# removed from test set:  Maine_Coon_79.jpg
# removed from test set:  Maine_Coon_87.jpg
# removed from test set:  Maine_Coon_54.jpg
# removed from test set:  Maine_Coon_80.jpg
# removed from test set:  Maine_Coon_241.jpg
# removed from test set:  Maine_Coon_24.jpg
# removed from test set:  Maine_Coon_242.jpg
# removed from test set:  Maine_Coon_253.jpg
#
# removed from test set:  boxer_22.jpg
# removed from test set:  boxer_191.jpg
# removed from test set:  boxer_31.jpg
# removed from test set:  boxer_33.jpg
# removed from test set:  boxer_195.jpg
# removed from test set:  boxer_82.jpg
# removed from test set:  boxer_69.jpg
# removed from test set:  boxer_41.jpg
# removed from test set:  boxer_81.jpg
# removed from test set:  boxer_57.jpg
# removed from test set:  boxer_47.jpg
# removed from test set:  boxer_87.jpg
# removed from test set:  boxer_45.jpg
# removed from test set:  boxer_86.jpg
# removed from test set:  boxer_61.jpg
# removed from test set:  boxer_63.jpg
# removed from test set:  boxer_59.jpg
# removed from test set:  boxer_199.jpg
# removed from test set:  boxer_29.jpg
# removed from test set:  boxer_39.jpg
#
# removed from test set:  chihuahua_62.jpg
# removed from test set:  chihuahua_200.jpg
# removed from test set:  chihuahua_75.jpg
# removed from test set:  chihuahua_199.jpg
# removed from test set:  chihuahua_198.jpg
# removed from test set:  chihuahua_98.jpg
# removed from test set:  chihuahua_73.jpg
# removed from test set:  chihuahua_29.jpg
# removed from test set:  chihuahua_20.jpg
# removed from test set:  chihuahua_33.jpg
# removed from test set:  chihuahua_25.jpg
# removed from test set:  chihuahua_81.jpg
# removed from test set:  chihuahua_95.jpg
# removed from test set:  chihuahua_194.jpg
# removed from test set:  chihuahua_80.jpg
# removed from test set:  chihuahua_43.jpg
# removed from test set:  chihuahua_197.jpg
# removed from test set:  chihuahua_93.jpg
# removed from test set:  chihuahua_45.jpg
# removed from test set:  chihuahua_90.jpg
# removed from test set:  chihuahua_6.jpg
#
# removed from test set:  yorkshire_terrier_19.jpg
# removed from test set:  yorkshire_terrier_24.jpg
# removed from test set:  yorkshire_terrier_56.jpg
# removed from test set:  yorkshire_terrier_83.jpg
# removed from test set:  yorkshire_terrier_54.jpg
# removed from test set:  yorkshire_terrier_68.jpg
# removed from test set:  yorkshire_terrier_86.jpg
# removed from test set:  yorkshire_terrier_87.jpg
# removed from test set:  yorkshire_terrier_85.jpg
# removed from test set:  yorkshire_terrier_46.jpg
# removed from test set:  yorkshire_terrier_198.jpg
# removed from test set:  yorkshire_terrier_53.jpg
# removed from test set:  yorkshire_terrier_76.jpg
# removed from test set:  yorkshire_terrier_195.jpg
# removed from test set:  yorkshire_terrier_194.jpg
# removed from test set:  yorkshire_terrier_77.jpg
# removed from test set:  yorkshire_terrier_196.jpg
# removed from test set:  yorkshire_terrier_197.jpg
# removed from test set:  yorkshire_terrier_74.jpg
# removed from test set:  yorkshire_terrier_71.jpg
# removed from test set:  yorkshire_terrier_98.jpg
# removed from test set:  yorkshire_terrier_4.jpg
# removed from test set:  yorkshire_terrier_39.jpg
#
# removed from test set:  german_shorthaired_63.jpg
# removed from test set:  german_shorthaired_74.jpg
# removed from test set:  german_shorthaired_38.jpg
# removed from test set:  german_shorthaired_39.jpg
# removed from test set:  german_shorthaired_5.jpg
# removed from test set:  german_shorthaired_196.jpg
# removed from test set:  german_shorthaired_36.jpg
# removed from test set:  german_shorthaired_22.jpg
# removed from test set:  german_shorthaired_78.jpg
# removed from test set:  german_shorthaired_52.jpg
# removed from test set:  german_shorthaired_47.jpg
# removed from test set:  german_shorthaired_53.jpg
# removed from test set:  german_shorthaired_94.jpg
# removed from test set:  german_shorthaired_57.jpg
# removed from test set:  german_shorthaired_56.jpg
# removed from test set:  german_shorthaired_95.jpg
# removed from test set:  german_shorthaired_97.jpg
# removed from test set:  german_shorthaired_55.jpg
# removed from test set:  german_shorthaired_96.jpg
# removed from test set:  german_shorthaired_82.jpg
#
# removed from test set:  miniature_pinscher_72.jpg
# removed from test set:  miniature_pinscher_70.jpg
# removed from test set:  miniature_pinscher_77.jpg
# removed from test set:  miniature_pinscher_62.jpg
# removed from test set:  miniature_pinscher_89.jpg
# removed from test set:  miniature_pinscher_6.jpg
# removed from test set:  miniature_pinscher_5.jpg
# removed from test set:  miniature_pinscher_33.jpg
# removed from test set:  miniature_pinscher_4.jpg
# removed from test set:  miniature_pinscher_20.jpg
# removed from test set:  miniature_pinscher_84.jpg
# removed from test set:  miniature_pinscher_53.jpg
# removed from test set:  miniature_pinscher_46.jpg
# removed from test set:  miniature_pinscher_91.jpg
# removed from test set:  miniature_pinscher_44.jpg
# removed from test set:  miniature_pinscher_96.jpg
# removed from test set:  miniature_pinscher_55.jpg
# removed from test set:  miniature_pinscher_192.jpg
# removed from test set:  miniature_pinscher_97.jpg
#
# removed from test set:  beagle_21.jpg
# removed from test set:  beagle_20.jpg
# removed from test set:  beagle_22.jpg
# removed from test set:  beagle_24.jpg
# removed from test set:  beagle_198.jpg
# removed from test set:  beagle_42.jpg
# removed from test set:  beagle_56.jpg
# removed from test set:  beagle_1.jpg
# removed from test set:  beagle_87.jpg
# removed from test set:  beagle_44.jpg
# removed from test set:  beagle_45.jpg
# removed from test set:  beagle_92.jpg
# removed from test set:  beagle_202.jpg
# removed from test set:  beagle_52.jpg
# removed from test set:  beagle_7.jpg
# removed from test set:  beagle_201.jpg
# removed from test set:  beagle_88.jpg
# removed from test set:  beagle_89.jpg
# removed from test set:  beagle_99.jpg
# removed from test set:  beagle_66.jpg
# removed from test set:  beagle_29.jpg
#
# removed from test set:  japanese_chin_1.jpg
# removed from test set:  japanese_chin_3.jpg
# removed from test set:  japanese_chin_38.jpg
# removed from test set:  japanese_chin_7.jpg
# removed from test set:  japanese_chin_194.jpg
# removed from test set:  japanese_chin_29.jpg
# removed from test set:  japanese_chin_4.jpg
# removed from test set:  japanese_chin_65.jpg
# removed from test set:  japanese_chin_70.jpg
# removed from test set:  japanese_chin_89.jpg
# removed from test set:  japanese_chin_49.jpg
# removed from test set:  japanese_chin_44.jpg
# removed from test set:  japanese_chin_50.jpg
# removed from test set:  japanese_chin_78.jpg
# removed from test set:  japanese_chin_93.jpg
# removed from test set:  japanese_chin_45.jpg
# removed from test set:  japanese_chin_46.jpg
# removed from test set:  japanese_chin_42.jpg
# removed from test set:  japanese_chin_57.jpg
# removed from test set:  japanese_chin_96.jpg
# removed from test set:  japanese_chin_24.jpg
# removed from test set:  japanese_chin_35.jpg
# removed from test set:  japanese_chin_34.jpg
#
# removed from test set:  saint_bernard_80.jpg
# removed from test set:  saint_bernard_46.jpg
# removed from test set:  saint_bernard_5.jpg
# removed from test set:  saint_bernard_198.jpg
# removed from test set:  saint_bernard_24.jpg
# removed from test set:  saint_bernard_25.jpg
# removed from test set:  saint_bernard_31.jpg
# removed from test set:  saint_bernard_27.jpg
# removed from test set:  saint_bernard_32.jpg
# removed from test set:  saint_bernard_200.jpg
# removed from test set:  saint_bernard_193.jpg
# removed from test set:  saint_bernard_192.jpg
# removed from test set:  saint_bernard_38.jpg
# removed from test set:  saint_bernard_197.jpg
# removed from test set:  saint_bernard_194.jpg
# removed from test set:  saint_bernard_74.jpg
# removed from test set:  saint_bernard_63.jpg
# removed from test set:  saint_bernard_71.jpg
# removed from test set:  saint_bernard_64.jpg
#
# removed from test set:  american_bulldog_8.jpg
# removed from test set:  american_bulldog_65.jpg
# removed from test set:  american_bulldog_70.jpg
# removed from test set:  american_bulldog_60.jpg
# removed from test set:  american_bulldog_49.jpg
# removed from test set:  american_bulldog_224.jpg
# removed from test set:  american_bulldog_30.jpg
# removed from test set:  american_bulldog_31.jpg
# removed from test set:  american_bulldog_25.jpg
# removed from test set:  american_bulldog_33.jpg
# removed from test set:  american_bulldog_26.jpg
# removed from test set:  american_bulldog_52.jpg
# removed from test set:  american_bulldog_203.jpg
# removed from test set:  american_bulldog_93.jpg
# removed from test set:  american_bulldog_50.jpg
# removed from test set:  american_bulldog_214.jpg
# removed from test set:  american_bulldog_83.jpg
# removed from test set:  american_bulldog_211.jpg
# removed from test set:  american_bulldog_81.jpg
# removed from test set:  american_bulldog_95.jpg
# removed from test set:  american_bulldog_80.jpg
# removed from test set:  american_bulldog_212.jpg
#
# removed from test set:  Persian_9.jpg
# removed from test set:  Persian_76.jpg
# removed from test set:  Persian_77.jpg
# removed from test set:  Persian_63.jpg
# removed from test set:  Persian_256.jpg
# removed from test set:  Persian_257.jpg
# removed from test set:  Persian_269.jpg
# removed from test set:  Persian_39.jpg
# removed from test set:  Persian_263.jpg
# removed from test set:  Persian_25.jpg
# removed from test set:  Persian_31.jpg
# removed from test set:  Persian_30.jpg
# removed from test set:  Persian_264.jpg
# removed from test set:  Persian_266.jpg
# removed from test set:  Persian_32.jpg
# removed from test set:  Persian_54.jpg
# removed from test set:  Persian_41.jpg
# removed from test set:  Persian_81.jpg
# removed from test set:  Persian_46.jpg
# removed from test set:  Persian_239.jpg
#
# removed from test set:  basset_hound_94.jpg
# removed from test set:  basset_hound_81.jpg
# removed from test set:  basset_hound_55.jpg
# removed from test set:  basset_hound_69.jpg
# removed from test set:  basset_hound_92.jpg
# removed from test set:  basset_hound_78.jpg
# removed from test set:  basset_hound_46.jpg
# removed from test set:  basset_hound_47.jpg
# removed from test set:  basset_hound_53.jpg
# removed from test set:  basset_hound_199.jpg
# removed from test set:  basset_hound_23.jpg
# removed from test set:  basset_hound_36.jpg
# removed from test set:  basset_hound_33.jpg
# removed from test set:  basset_hound_31.jpg
# removed from test set:  basset_hound_25.jpg
# removed from test set:  basset_hound_193.jpg
# removed from test set:  basset_hound_194.jpg
# removed from test set:  basset_hound_38.jpg
# removed from test set:  basset_hound_197.jpg
# removed from test set:  basset_hound_49.jpg
#
# removed from test set:  english_setter_26.jpg
# removed from test set:  english_setter_200.jpg
# removed from test set:  english_setter_35.jpg
# removed from test set:  english_setter_22.jpg
# removed from test set:  english_setter_44.jpg
# removed from test set:  english_setter_87.jpg
# removed from test set:  english_setter_51.jpg
# removed from test set:  english_setter_84.jpg
# removed from test set:  english_setter_42.jpg
# removed from test set:  english_setter_81.jpg
# removed from test set:  english_setter_68.jpg
# removed from test set:  english_setter_40.jpg
# removed from test set:  english_setter_70.jpg
# removed from test set:  english_setter_66.jpg
# removed from test set:  english_setter_98.jpg
# removed from test set:  english_setter_89.jpg
# removed from test set:  english_setter_76.jpg
# removed from test set:  english_setter_49.jpg
# removed from test set:  english_setter_75.jpg
# removed from test set:  english_setter_3.jpg
# removed from test set:  english_setter_28.jpg
# removed from test set:  english_setter_6.jpg
#
# removed from test set:  newfoundland_63.jpg
# removed from test set:  newfoundland_88.jpg
# removed from test set:  newfoundland_71.jpg
# removed from test set:  newfoundland_67.jpg
# removed from test set:  newfoundland_197.jpg
# removed from test set:  newfoundland_191.jpg
# removed from test set:  newfoundland_1.jpg
# removed from test set:  newfoundland_153.jpg
# removed from test set:  newfoundland_2.jpg
# removed from test set:  newfoundland_20.jpg
# removed from test set:  newfoundland_23.jpg
# removed from test set:  newfoundland_8.jpg
# removed from test set:  newfoundland_27.jpg
# removed from test set:  newfoundland_56.jpg
# removed from test set:  newfoundland_55.jpg
# removed from test set:  newfoundland_54.jpg
# removed from test set:  newfoundland_50.jpg
# removed from test set:  newfoundland_78.jpg
# removed from test set:  newfoundland_87.jpg
# removed from test set:  newfoundland_45.jpg
#
# removed from test set:  scottish_terrier_30.jpg
# removed from test set:  scottish_terrier_31.jpg
# removed from test set:  scottish_terrier_25.jpg
# removed from test set:  scottish_terrier_33.jpg
# removed from test set:  scottish_terrier_27.jpg
# removed from test set:  scottish_terrier_90.jpg
# removed from test set:  scottish_terrier_191.jpg
# removed from test set:  scottish_terrier_78.jpg
# removed from test set:  scottish_terrier_79.jpg
# removed from test set:  scottish_terrier_7.jpg
# removed from test set:  scottish_terrier_3.jpg
# removed from test set:  scottish_terrier_2.jpg
# removed from test set:  scottish_terrier_195.jpg
# removed from test set:  scottish_terrier_196.jpg
# removed from test set:  scottish_terrier_72.jpg
# removed from test set:  scottish_terrier_65.jpg
# removed from test set:  scottish_terrier_61.jpg
# removed from test set:  scottish_terrier_63.jpg
# removed from test set:  scottish_terrier_77.jpg
# removed from test set:  scottish_terrier_89.jpg
#
# removed from test set:  Bombay_97.jpg
# removed from test set:  Bombay_206.jpg
# removed from test set:  Bombay_81.jpg
# removed from test set:  Bombay_57.jpg
# removed from test set:  Bombay_90.jpg
# removed from test set:  Bombay_87.jpg
# removed from test set:  Bombay_86.jpg
# removed from test set:  Bombay_203.jpg
# removed from test set:  Bombay_21.jpg
# removed from test set:  Bombay_34.jpg
# removed from test set:  Bombay_20.jpg
# removed from test set:  Bombay_30.jpg
# removed from test set:  Bombay_25.jpg
# removed from test set:  Bombay_4.jpg
# removed from test set:  Bombay_190.jpg
# removed from test set:  Bombay_89.jpg
# removed from test set:  Bombay_220.jpg
# removed from test set:  Bombay_208.jpg
# removed from test set:  Bombay_66.jpg
# removed from test set:  Bombay_59.jpg
# removed from test set:  Bombay_64.jpg
#
# removed from test set:  Ragdoll_32.jpg
# removed from test set:  Ragdoll_203.jpg
# removed from test set:  Ragdoll_7.jpg
# removed from test set:  Ragdoll_6.jpg
# removed from test set:  Ragdoll_3.jpg
# removed from test set:  Ragdoll_34.jpg
# removed from test set:  Ragdoll_204.jpg
# removed from test set:  Ragdoll_210.jpg
# removed from test set:  Ragdoll_52.jpg
# removed from test set:  Ragdoll_262.jpg
# removed from test set:  Ragdoll_53.jpg
# removed from test set:  Ragdoll_92.jpg
# removed from test set:  Ragdoll_94.jpg
# removed from test set:  Ragdoll_56.jpg
# removed from test set:  Ragdoll_42.jpg
# removed from test set:  Ragdoll_64.jpg
# removed from test set:  Ragdoll_75.jpg
# removed from test set:  Ragdoll_49.jpg
# removed from test set:  Ragdoll_234.jpg
# removed from test set:  Ragdoll_8.jpg
#
# removed from test set:  Bengal_67.jpg
# removed from test set:  Bengal_75.jpg
# removed from test set:  Bengal_38.jpg
# removed from test set:  Bengal_9.jpg
# removed from test set:  Bengal_199.jpg
# removed from test set:  Bengal_24.jpg
# removed from test set:  Bengal_195.jpg
# removed from test set:  Bengal_3.jpg
# removed from test set:  Bengal_196.jpg
# removed from test set:  Bengal_4.jpg
# removed from test set:  Bengal_91.jpg
# removed from test set:  Bengal_52.jpg
# removed from test set:  Bengal_46.jpg
# removed from test set:  Bengal_92.jpg
# removed from test set:  Bengal_51.jpg
# removed from test set:  Bengal_82.jpg
# removed from test set:  Bengal_54.jpg
# removed from test set:  Bengal_42.jpg
#
# removed from test set:  staffordshire_bull_terrier_8.jpg
# removed from test set:  staffordshire_bull_terrier_9.jpg
# removed from test set:  staffordshire_bull_terrier_64.jpg
# removed from test set:  staffordshire_bull_terrier_75.jpg
# removed from test set:  staffordshire_bull_terrier_200.jpg
# removed from test set:  staffordshire_bull_terrier_63.jpg
# removed from test set:  staffordshire_bull_terrier_47.jpg
# removed from test set:  staffordshire_bull_terrier_91.jpg
# removed from test set:  staffordshire_bull_terrier_55.jpg
# removed from test set:  staffordshire_bull_terrier_57.jpg
# removed from test set:  staffordshire_bull_terrier_80.jpg
# removed from test set:  staffordshire_bull_terrier_30.jpg
# removed from test set:  staffordshire_bull_terrier_25.jpg
# removed from test set:  staffordshire_bull_terrier_33.jpg
# removed from test set:  staffordshire_bull_terrier_32.jpg
# removed from test set:  staffordshire_bull_terrier_4.jpg
# removed from test set:  staffordshire_bull_terrier_36.jpg
# removed from test set:  staffordshire_bull_terrier_37.jpg
# removed from test set:  staffordshire_bull_terrier_5.jpg
# removed from test set:  staffordshire_bull_terrier_21.jpg
#
# removed from test set:  havanese_99.jpg
# removed from test set:  havanese_64.jpg
# removed from test set:  havanese_76.jpg
# removed from test set:  havanese_52.jpg
# removed from test set:  havanese_85.jpg
# removed from test set:  havanese_87.jpg
# removed from test set:  havanese_51.jpg
# removed from test set:  havanese_45.jpg
# removed from test set:  havanese_92.jpg
# removed from test set:  havanese_194.jpg
# removed from test set:  havanese_69.jpg
# removed from test set:  havanese_54.jpg
# removed from test set:  havanese_83.jpg
# removed from test set:  havanese_5.jpg
# removed from test set:  havanese_31.jpg
# removed from test set:  havanese_26.jpg
# removed from test set:  havanese_22.jpg
# removed from test set:  havanese_3.jpg
# removed from test set:  havanese_2.jpg
#
# removed from test set:  British_Shorthair_277.jpg
# removed from test set:  British_Shorthair_266.jpg
# removed from test set:  British_Shorthair_272.jpg
# removed from test set:  British_Shorthair_48.jpg
# removed from test set:  British_Shorthair_62.jpg
# removed from test set:  British_Shorthair_258.jpg
# removed from test set:  British_Shorthair_8.jpg
# removed from test set:  British_Shorthair_63.jpg
# removed from test set:  British_Shorthair_91.jpg
# removed from test set:  British_Shorthair_46.jpg
# removed from test set:  British_Shorthair_53.jpg
# removed from test set:  British_Shorthair_79.jpg
# removed from test set:  British_Shorthair_45.jpg
# removed from test set:  British_Shorthair_2.jpg
# removed from test set:  British_Shorthair_96.jpg
# removed from test set:  British_Shorthair_278.jpg
# removed from test set:  British_Shorthair_31.jpg
# removed from test set:  British_Shorthair_33.jpg
# removed from test set:  British_Shorthair_230.jpg
# removed from train set:  basset_hound_106.jpg
# removed from train set:  basset_hound_113.jpg
# removed from train set:  basset_hound_110.jpg
# removed from train set:  basset_hound_115.jpg
# removed from train set:  basset_hound_103.jpg
# removed from train set:  basset_hound_102.jpg
# removed from train set:  basset_hound_116.jpg
# removed from train set:  basset_hound_164.jpg
# removed from train set:  basset_hound_172.jpg
# removed from train set:  basset_hound_163.jpg
# removed from train set:  basset_hound_18.jpg
# removed from train set:  basset_hound_178.jpg
# removed from train set:  basset_hound_184.jpg
# removed from train set:  basset_hound_190.jpg
# removed from train set:  basset_hound_185.jpg
# removed from train set:  basset_hound_181.jpg
# removed from train set:  basset_hound_183.jpg
# removed from train set:  basset_hound_109.jpg
# removed from train set:  basset_hound_121.jpg
# removed from train set:  basset_hound_134.jpg
# removed from train set:  Siamese_178.jpg
# removed from train set:  Siamese_179.jpg
# removed from train set:  Siamese_191.jpg
# removed from train set:  Siamese_181.jpg
# removed from train set:  Siamese_208.jpg
# removed from train set:  Siamese_155.jpg
# removed from train set:  Siamese_141.jpg
# removed from train set:  Siamese_18.jpg
# removed from train set:  Siamese_133.jpg
# removed from train set:  Siamese_131.jpg
# removed from train set:  Siamese_110.jpg
# removed from train set:  Siamese_100.jpg
# removed from train set:  Siamese_117.jpg
# removed from train set:  Siamese_165.jpg
# removed from train set:  Siamese_159.jpg
# removed from train set:  Siamese_198.jpg
# removed from train set:  Siamese_148.jpg
# removed from train set:  Siamese_202.jpg
# removed from train set:  Siamese_161.jpg
# removed from train set:  shiba_inu_135.jpg
# removed from train set:  wheaten_terrier_137.jpg
# removed from train set:  wheaten_terrier_127.jpg
# removed from train set:  wheaten_terrier_16.jpg
# removed from train set:  wheaten_terrier_181.jpg
# removed from train set:  wheaten_terrier_143.jpg
# removed from train set:  wheaten_terrier_17.jpg
# removed from train set:  wheaten_terrier_182.jpg
# removed from train set:  wheaten_terrier_150.jpg
# removed from train set:  wheaten_terrier_151.jpg
# removed from train set:  wheaten_terrier_145.jpg
# removed from train set:  wheaten_terrier_190.jpg
# removed from train set:  wheaten_terrier_184.jpg
# removed from train set:  wheaten_terrier_177.jpg
# removed from train set:  wheaten_terrier_163.jpg
# removed from train set:  wheaten_terrier_160.jpg
# removed from train set:  wheaten_terrier_101.jpg
# removed from train set:  wheaten_terrier_115.jpg
# removed from train set:  wheaten_terrier_103.jpg
# removed from train set:  wheaten_terrier_117.jpg
# removed from train set:  wheaten_terrier_104.jpg

# %%
_, _, breeds_test = count_file_formats_dimensions_and_breeds(test_path)
print("breeds_test: ", breeds_test)
_, _, breeds_train = count_file_formats_dimensions_and_breeds(train_path)
print("breeds_train: ", breeds_train)
# Out:
# breeds_test:  {'wheaten_terrier': 19, 'Sphynx': 21, 'Egyptian_Mau': 20, 'Birman': 21, 'pomeranian': 20, 'Maine_Coon': 21, 'leonberger': 20, 'chihuahua': 22, 'yorkshire_terrier': 23, 'german_shorthaired': 20, 'miniature_pinscher': 19, 'boxer': 21, 'saint_bernard': 19, 'Persian': 21, 'english_setter': 22, 'Abyssinian': 20, 'american_bulldog': 23, 'Bombay': 21, 'newfoundland': 21, 'Ragdoll': 20, 'japanese_chin': 23, 'Siamese': 19, 'keeshond': 20, 'american_pit_bull_terrier': 19, 'shiba_inu': 20, 'pug': 22, 'basset_hound': 21, 'Russian_Blue': 21, 'beagle': 22, 'samoyed': 22, 'Bengal': 19, 'english_cocker_spaniel': 18, 'great_pyrenees': 21, 'scottish_terrier': 20, 'staffordshire_bull_terrier': 21, 'havanese': 19, 'British_Shorthair': 19}
# breeds_train:  {'basset_hound': 21, 'Siamese': 19, 'shiba_inu': 21, 'scottish_terrier': 21, 'english_setter': 22, 'great_pyrenees': 21, 'japanese_chin': 20, 'Maine_Coon': 21, 'boxer': 20, 'miniature_pinscher': 20, 'american_bulldog': 19, 'beagle': 21, 'staffordshire_bull_terrier': 19, 'Persian': 21, 'British_Shorthair': 21, 'yorkshire_terrier': 18, 'english_cocker_spaniel': 20, 'pug': 23, 'Russian_Blue': 21, 'samoyed': 23, 'Bengal': 21, 'keeshond': 20, 'Sphynx': 20, 'american_pit_bull_terrier': 21, 'havanese': 21, 'pomeranian': 20, 'german_shorthaired': 20, 'Egyptian_Mau': 17, 'Birman': 22, 'leonberger': 23, 'Ragdoll': 23, 'Abyssinian': 18, 'chihuahua': 21, 'wheaten_terrier': 20, 'Bombay': 19, 'newfoundland': 19, 'saint_bernard': 19}

# %%
test_sum = sum(breeds_test.values())
train_sum = sum(breeds_train.values())
print("Total number of images in test set: ", test_sum)
print("Total number of images in train set: ", train_sum)
# Out:
# Total number of images in test set:  760
# Total number of images in train set:  756
